# %% [markdown]
# # Import

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Open file

# %%
df = pd.read_csv("players.csv")

# %%
df
# Out:
#            surname     team    position  minutes  shots  passes  tackles  \
# 0           Abdoun  Algeria  midfielder       16      0       6        0
# 1          Belhadj  Algeria    defender      270      1     146        8
# 2        Boudebouz  Algeria  midfielder       74      3      28        1
# 3        Bougherra  Algeria    defender      270      1      89       11
# 4         Chaouchi  Algeria  goalkeeper       90      0      17        0
# ..             ...      ...         ...      ...    ...     ...      ...
# 590         Holden      USA  midfielder        4      0       2        0
# 591         Howard      USA  goalkeeper      390      0      81        0
# 592  Jozy Altidore      USA     forward      356      8      84        2
# 593         Onyewu      USA    defender      170      1      69        2
# 594         Torres      USA  midfielder       45      1      32        0
#
#      saves  Unnamed: 8  Unnamed: 9  ...  Unnamed: 16  Unnamed: 17  \
# ...

# %%
pd.read_csv('players.csv', usecols=range(0,8), skiprows=[1,2])
# Out:
#            surname     team    position  minutes  shots  passes  tackles  \
# 0        Boudebouz  Algeria  midfielder       74      3      28        1
# 1        Bougherra  Algeria    defender      270      1      89       11
# 2         Chaouchi  Algeria  goalkeeper       90      0      17        0
# 3         Djebbour  Algeria     forward      123      3      19        1
# 4          Ghezzal  Algeria     forward       40      3       8        0
# ..             ...      ...         ...      ...    ...     ...      ...
# 588         Holden      USA  midfielder        4      0       2        0
# 589         Howard      USA  goalkeeper      390      0      81        0
# 590  Jozy Altidore      USA     forward      356      8      84        2
# 591         Onyewu      USA    defender      170      1      69        2
# 592         Torres      USA  midfielder       45      1      32        0
#
#      saves
# 0        0
# 1        0
# 2        2
# 3        0
# 4        0
# ..     ...
# ...

# %% [markdown]
# # Inspection

# %%
df = pd.read_csv("players.csv", usecols=range(0,8))

# %%
df.shape # Row not include header, Col not include index
# Out:
# (595, 8)

# %%
df.columns
# Out:
# Index(['surname', 'team', 'position', 'minutes', 'shots', 'passes', 'tackles',
#        'saves'],
#       dtype='object')

# %%
old_col = df.columns

# %%
df.columns = ['Surname', 'Team', 'Position', 'Minutes', 'Shots', 'Passes', 'Tackles',
       'saves'] # Change the name of column

# %%
df
# Out:
#            Surname     Team    Position  Minutes  Shots  Passes  Tackles  \
# 0           Abdoun  Algeria  midfielder       16      0       6        0
# 1          Belhadj  Algeria    defender      270      1     146        8
# 2        Boudebouz  Algeria  midfielder       74      3      28        1
# 3        Bougherra  Algeria    defender      270      1      89       11
# 4         Chaouchi  Algeria  goalkeeper       90      0      17        0
# ..             ...      ...         ...      ...    ...     ...      ...
# 590         Holden      USA  midfielder        4      0       2        0
# 591         Howard      USA  goalkeeper      390      0      81        0
# 592  Jozy Altidore      USA     forward      356      8      84        2
# 593         Onyewu      USA    defender      170      1      69        2
# 594         Torres      USA  midfielder       45      1      32        0
#
#      saves
# 0        0
# 1        0
# 2        0
# 3        0
# 4        2
# ..     ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 595 entries, 0 to 594
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Surname   595 non-null    object
#  1   Team      595 non-null    object
#  2   Position  595 non-null    object
#  3   Minutes   595 non-null    int64
#  4   Shots     595 non-null    int64
#  5   Passes    595 non-null    int64
#  6   Tackles   595 non-null    int64
#  7   saves     595 non-null    int64
# dtypes: int64(5), object(3)
# memory usage: 37.3+ KB

# %%
df.index
# Out:
# RangeIndex(start=0, stop=595, step=1)

# %%
df = df.set_index('Surname')
df
# Out:
#                   Team    Position  Minutes  Shots  Passes  Tackles  saves
# Surname
# Abdoun         Algeria  midfielder       16      0       6        0      0
# Belhadj        Algeria    defender      270      1     146        8      0
# Boudebouz      Algeria  midfielder       74      3      28        1      0
# Bougherra      Algeria    defender      270      1      89       11      0
# Chaouchi       Algeria  goalkeeper       90      0      17        0      2
# ...                ...         ...      ...    ...     ...      ...    ...
# Holden             USA  midfielder        4      0       2        0      0
# Howard             USA  goalkeeper      390      0      81        0     14
# Jozy Altidore      USA     forward      356      8      84        2      0
# Onyewu             USA    defender      170      1      69        2      0
# Torres             USA  midfielder       45      1      32        0      0
#
# [595 rows x 7 columns]

# %%
df = df.reset_index()
df
# Out:
#            Surname     Team    Position  Minutes  Shots  Passes  Tackles  \
# 0           Abdoun  Algeria  midfielder       16      0       6        0
# 1          Belhadj  Algeria    defender      270      1     146        8
# 2        Boudebouz  Algeria  midfielder       74      3      28        1
# 3        Bougherra  Algeria    defender      270      1      89       11
# 4         Chaouchi  Algeria  goalkeeper       90      0      17        0
# ..             ...      ...         ...      ...    ...     ...      ...
# 590         Holden      USA  midfielder        4      0       2        0
# 591         Howard      USA  goalkeeper      390      0      81        0
# 592  Jozy Altidore      USA     forward      356      8      84        2
# 593         Onyewu      USA    defender      170      1      69        2
# 594         Torres      USA  midfielder       45      1      32        0
#
#      saves
# 0        0
# 1        0
# 2        0
# 3        0
# 4        2
# ..     ...
# ...

# %% [markdown]
# # Selection iloc

# %%
df = df.set_index('Surname')

# %%
df.iloc[0, 1] # [row, column]
# Out:
# 'midfielder'

# %%
df.iloc[[3, 5, 2], [0, 1, 2, 3]] # [[row], [column]]
# Out:
#               Team    Position  Minutes  Shots
# Surname
# Bougherra  Algeria    defender      270      1
# Djebbour   Algeria     forward      123      3
# Boudebouz  Algeria  midfielder       74      3

# %%
df.iloc[:10, :8:2]
# Out:
#               Team  Minutes  Passes  saves
# Surname
# Abdoun     Algeria       16       6      0
# Belhadj    Algeria      270     146      0
# Boudebouz  Algeria       74      28      0
# Bougherra  Algeria      270      89      0
# Chaouchi   Algeria       90      17      2
# Djebbour   Algeria      123      19      0
# Ghezzal    Algeria       40       8      0
# Guedioura  Algeria       38      18      0
# Halliche   Algeria      270      94      0
# Kadir      Algeria      262     104      0

# %% [markdown]
# # Selection loc

# %%
df.loc['Abdoun', 'Team']
# Out:
# 'Algeria'

# %%
df.loc[['Abdoun', 'Messi', 'Ronaldo'], ['Position', 'Team', 'Shots']]
# Out:
#            Position       Team  Shots
# Surname
# Abdoun   midfielder    Algeria      0
# Messi       forward  Argentina     21
# Ronaldo     forward   Portugal     18

# %%
df.loc['Abdoun':'Chaouchi', 'Team':'Shots']
# Out:
#               Team    Position  Minutes  Shots
# Surname
# Abdoun     Algeria  midfielder       16      0
# Belhadj    Algeria    defender      270      1
# Boudebouz  Algeria  midfielder       74      3
# Bougherra  Algeria    defender      270      1
# Chaouchi   Algeria  goalkeeper       90      0

# %%
df.loc[:, 'Team':'Shots']
# Out:
#                   Team    Position  Minutes  Shots
# Surname
# Abdoun         Algeria  midfielder       16      0
# Belhadj        Algeria    defender      270      1
# Boudebouz      Algeria  midfielder       74      3
# Bougherra      Algeria    defender      270      1
# Chaouchi       Algeria  goalkeeper       90      0
# ...                ...         ...      ...    ...
# Holden             USA  midfielder        4      0
# Howard             USA  goalkeeper      390      0
# Jozy Altidore      USA     forward      356      8
# Onyewu             USA    defender      170      1
# Torres             USA  midfielder       45      1
#
# [595 rows x 4 columns]

# %% [markdown]
# # Selection shortcuts

# %%
df['Team'] # Show as serie
# Out:
# Surname
# Abdoun           Algeria
# Belhadj          Algeria
# Boudebouz        Algeria
# Bougherra        Algeria
# Chaouchi         Algeria
#                   ...
# Holden               USA
# Howard               USA
# Jozy Altidore        USA
# Onyewu               USA
# Torres               USA
# Name: Team, Length: 595, dtype: object

# %%
df.Team # Show as serie
# Out:
# Surname
# Abdoun           Algeria
# Belhadj          Algeria
# Boudebouz        Algeria
# Bougherra        Algeria
# Chaouchi         Algeria
#                   ...
# Holden               USA
# Howard               USA
# Jozy Altidore        USA
# Onyewu               USA
# Torres               USA
# Name: Team, Length: 595, dtype: object

# %%
df[['Team']] # add [] if you want to show as dataframe
# Out:
#                   Team
# Surname
# Abdoun         Algeria
# Belhadj        Algeria
# Boudebouz      Algeria
# Bougherra      Algeria
# Chaouchi       Algeria
# ...                ...
# Holden             USA
# Howard             USA
# Jozy Altidore      USA
# Onyewu             USA
# Torres             USA
#
# [595 rows x 1 columns]

# %%
df.iloc[0] # df.iloc[0, :]
# Out:
# Team           Algeria
# Position    midfielder
# Minutes             16
# Shots                0
# Passes               6
# Tackles              0
# saves                0
# Name: Abdoun, dtype: object

# %% [markdown]
# # Filter (on rows)

# %%
df.Shots >= 20
# Out:
# Surname
# Abdoun           False
# Belhadj          False
# Boudebouz        False
# Bougherra        False
# Chaouchi         False
#                  ...
# Holden           False
# Howard           False
# Jozy Altidore    False
# Onyewu           False
# Torres           False
# Name: Shots, Length: 595, dtype: bool

# %%
df.loc[df.Shots >= 20, :]
# Out:
#               Team Position  Minutes  Shots  Passes  Tackles  saves
# Surname
# Messi    Argentina  forward      450     21     321       10      0
# Gyan         Ghana  forward      501     27     151        1      0
# Villa        Spain  forward      529     22     169        2      0

# %%
df[df.Shots >= 20]
# Out:
#               Team Position  Minutes  Shots  Passes  Tackles  saves
# Surname
# Messi    Argentina  forward      450     21     321       10      0
# Gyan         Ghana  forward      501     27     151        1      0
# Villa        Spain  forward      529     22     169        2      0

# %%
df[(df.Passes >= 300) & (df.Minutes < 530)] # don't forget () for each condition
# Out:
#                Team    Position  Minutes  Shots  Passes  Tackles  saves
# Surname
# Messi     Argentina     forward      450     21     321       10      0
# Annan         Ghana  midfielder      510      4     307       11      0
# Alonso        Spain  midfielder      506      9     465       18      0
# Busquets      Spain  midfielder      511      0     466       15      0
# Xavi          Spain  midfielder      515      4     563        6      0

# %% [markdown]
# # Dropping rows/columns

# %%
df = df.iloc[:, :7]

# %%
df
# Out:
#                   Team    Position  Minutes  Shots  Passes  Tackles  saves
# Surname
# Abdoun         Algeria  midfielder       16      0       6        0      0
# Belhadj        Algeria    defender      270      1     146        8      0
# Boudebouz      Algeria  midfielder       74      3      28        1      0
# Bougherra      Algeria    defender      270      1      89       11      0
# Chaouchi       Algeria  goalkeeper       90      0      17        0      2
# ...                ...         ...      ...    ...     ...      ...    ...
# Holden             USA  midfielder        4      0       2        0      0
# Howard             USA  goalkeeper      390      0      81        0     14
# Jozy Altidore      USA     forward      356      8      84        2      0
# Onyewu             USA    defender      170      1      69        2      0
# Torres             USA  midfielder       45      1      32        0      0
#
# [595 rows x 7 columns]

# %%
df.drop('Position', axis='columns')
# Out:
#                   Team  Minutes  Shots  Passes  Tackles  saves
# Surname
# Abdoun         Algeria       16      0       6        0      0
# Belhadj        Algeria      270      1     146        8      0
# Boudebouz      Algeria       74      3      28        1      0
# Bougherra      Algeria      270      1      89       11      0
# Chaouchi       Algeria       90      0      17        0      2
# ...                ...      ...    ...     ...      ...    ...
# Holden             USA        4      0       2        0      0
# Howard             USA      390      0      81        0     14
# Jozy Altidore      USA      356      8      84        2      0
# Onyewu             USA      170      1      69        2      0
# Torres             USA       45      1      32        0      0
#
# [595 rows x 6 columns]

# %%
df.drop(['Abdoun', 'Belhadj'], axis='index')
# Out:
#                   Team    Position  Minutes  Shots  Passes  Tackles  saves
# Surname
# Boudebouz      Algeria  midfielder       74      3      28        1      0
# Bougherra      Algeria    defender      270      1      89       11      0
# Chaouchi       Algeria  goalkeeper       90      0      17        0      2
# Djebbour       Algeria     forward      123      3      19        1      0
# Ghezzal        Algeria     forward       40      3       8        0      0
# ...                ...         ...      ...    ...     ...      ...    ...
# Holden             USA  midfielder        4      0       2        0      0
# Howard             USA  goalkeeper      390      0      81        0     14
# Jozy Altidore      USA     forward      356      8      84        2      0
# Onyewu             USA    defender      170      1      69        2      0
# Torres             USA  midfielder       45      1      32        0      0
#
# [593 rows x 7 columns]

# %% [markdown]
# # New Column

# %%
df['Hours'] = df.Minutes / 60 # WARNING: It's change original table

# %%
df
# Out:
#                   Team    Position  Minutes  Shots  Passes  Tackles  saves  \
# Surname
# Abdoun         Algeria  midfielder       16      0       6        0      0
# Belhadj        Algeria    defender      270      1     146        8      0
# Boudebouz      Algeria  midfielder       74      3      28        1      0
# Bougherra      Algeria    defender      270      1      89       11      0
# Chaouchi       Algeria  goalkeeper       90      0      17        0      2
# ...                ...         ...      ...    ...     ...      ...    ...
# Holden             USA  midfielder        4      0       2        0      0
# Howard             USA  goalkeeper      390      0      81        0     14
# Jozy Altidore      USA     forward      356      8      84        2      0
# Onyewu             USA    defender      170      1      69        2      0
# Torres             USA  midfielder       45      1      32        0      0
#
#                   Hours
# Surname
# ...

# %% [markdown]
# # New row

# %%
new_player = pd.Series(['Thailand', 'midfielder', 0, 0, 0, 0, 0, 0], name='Seth'
                      ,index=df.columns)

# %%
new_player
# Out:
# Team          Thailand
# Position    midfielder
# Minutes              0
# Shots                0
# Passes               0
# Tackles              0
# saves                0
# Hours                0
# Name: Seth, dtype: object

# %%
df.append(new_player)
# Out:
# /var/folders/31/jkvnd89x7zj51y8qmlmsmgh00000gn/T/ipykernel_46233/2984993203.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df.append(new_player)
#                    Team    Position  Minutes  Shots  Passes  Tackles  saves  \
# Surname
# Abdoun          Algeria  midfielder       16      0       6        0      0
# Belhadj         Algeria    defender      270      1     146        8      0
# Boudebouz       Algeria  midfielder       74      3      28        1      0
# Bougherra       Algeria    defender      270      1      89       11      0
# Chaouchi        Algeria  goalkeeper       90      0      17        0      2
# ...                 ...         ...      ...    ...     ...      ...    ...
# Howard              USA  goalkeeper      390      0      81        0     14
# Jozy Altidore       USA     forward      356      8      84        2      0
# ...

# %% [markdown]
# #  Sort

# %%
df.sort_index(ascending=False)
# Out:
#                         Team    Position  Minutes  Shots  Passes  Tackles  \
# Surname
# von Bergen       Switzerland    defender      234      0      79        3
# van Persie       Netherlands     forward      479     14     108        1
# van Bronckhorst  Netherlands    defender      540      1     271       10
# van Bommel       Netherlands  midfielder      540      2     307       31
# de Zeeuw         Netherlands  midfielder       47      0      37        2
# ...                      ...         ...      ...    ...     ...      ...
# Aboubakar           Cameroon     forward       46      2      16        0
# Abou Diaby            France  midfielder      270      1     111        5
# Abidal                France    defender      180      0      91        6
# Abe                    Japan  midfielder      351      0     101       14
# Abdoun               Algeria  midfielder       16      0       6        0
#
#                  saves     Hours
# Surname
# ...

# %%
df.sort_values('Passes', ascending=False).head(10)
# Out:
#                        Team    Position  Minutes  Shots  Passes  Tackles  \
# Surname
# Xavi                  Spain  midfielder      515      4     563        6
# Busquets              Spain  midfielder      511      0     466       15
# Alonso                Spain  midfielder      506      9     465       18
# Schweinsteiger      Germany  midfielder      531      5     423       23
# Pique                 Spain    defender      540      2     402       15
# Lahm                Germany    defender      540      0     360       17
# Messi             Argentina     forward      450     21     321       10
# Capdevila             Spain    defender      540      1     310       10
# Annan                 Ghana  midfielder      510      4     307       11
# van Bommel      Netherlands  midfielder      540      2     307       31
#
#                 saves     Hours
# Surname
# Xavi                0  8.583333
# Busquets            0  8.516667
# Alonso              0  8.433333
# ...

# %%
df.sort_values(['Passes', 'Tackles'], ascending=[False, False]).head(20)
# Out:
#                         Team    Position  Minutes  Shots  Passes  Tackles  \
# Surname
# Xavi                   Spain  midfielder      515      4     563        6
# Busquets               Spain  midfielder      511      0     466       15
# Alonso                 Spain  midfielder      506      9     465       18
# Schweinsteiger       Germany  midfielder      531      5     423       23
# Pique                  Spain    defender      540      2     402       15
# Lahm                 Germany    defender      540      0     360       17
# Messi              Argentina     forward      450     21     321       10
# Capdevila              Spain    defender      540      1     310       10
# van Bommel       Netherlands  midfielder      540      2     307       31
# Annan                  Ghana  midfielder      510      4     307       11
# Gilberto Silva        Brazil  midfielder      450      3     299       11
# ...

# %% [markdown]
# # Methods

# %%
df.mean()
# Out:
# /var/folders/31/jkvnd89x7zj51y8qmlmsmgh00000gn/T/ipykernel_46233/3698961737.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# Minutes    208.863866
# Shots        2.304202
# Passes      84.521008
# Tackles      4.191597
# saves        0.667227
# Hours        3.481064
# dtype: float64

# %%
df.mean(axis='columns')
# Out:
# /var/folders/31/jkvnd89x7zj51y8qmlmsmgh00000gn/T/ipykernel_46233/1618129976.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.mean(axis='columns')
# Surname
# Abdoun            3.711111
# Belhadj          71.583333
# Boudebouz        17.872222
# Bougherra        62.583333
# Chaouchi         18.416667
#                    ...
# Holden            1.011111
# Howard           81.916667
# Jozy Altidore    75.988889
# Onyewu           40.805556
# Torres           13.125000
# Length: 595, dtype: float64
